# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateus-Silva98/python_curso_pandas/blob/main/Aula_07_An%C3%A1lise_de_dados_EDA_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise Exploratória de Dados**

# %% [markdown]
# #### Todos os direitos reservados. Data Viking.

# %% [markdown]
# <a id="home"></a>
# ## **Agenda**

# %% [markdown]
# * [Introdução à Análise de Dados](#introduction_da)
# * [Pipeline da EDA](#pipeline_eda)
#     * [1. Reconhecimentos de Atributos](#atributes)
#     * [2. Análise Univariada](#univariate)
#     * [3. Análise Multivariada](#multivariate)
#     * [4. Deteção de Anomalias](#aberrant)
#     * [5. Deteção de Outliers](#outliers)
#     * [6. Engenharia de Features](#feature_eng)
# * [Hands On!](#hands_on_eda)
# * [Homework](#homework)
# * [Para aprofundar](#next_steps)
# * [Referências](#ref)

# %% [markdown]
# <a id="introduction_da"></a>
# ## **Introdução à Análise de Dados**

# %% [markdown]
# A análise de dados é uma área que envolve a prática constante de transformar dados brutos em informações úteis, visando a melhoria do negócio e a melhoria de performance das empresas frente às transformações digitais que ocorrem atualmente.
#
# Esta época é chamada de Era da Informação, onde os dados são considerados o novo petróleo, pois a partir deles é possível gerar informações que vão impactar diretamente na competitividade e no sucesso da empresa frente ao mercado. Por isso, atualmente, o processo organizacional como um todo é voltado e orientado a dados.
#
# Com a transformação digital e o foco nos dados, as empresas passam a lidar com o tratamento de grandes volumes de dados, gerados e coletados em alta velocidade e a partir de diversas fontes e tipos. Este fenômeno é conhecido como Big Data.
#
# Para que os dados possam ser analisados, são utilizados diversos conceitos fundamentais de computação e matemática, os mesmos que formam em conjunto os conceitos gerais da ciência e mineração de dados.
#
# Para entendermos melhor esses conceitos, temos que esclarecer algumas terminologias básicas utilizadas comumente. São elas:
#
# **Ordem de Significado**
#
# 1. Dados: consiste em fatos discretos que representam a base da informação, porém ainda não possuem significado qualquer;
# 2. Informação: consiste na organização e estruturação dos fatos, aplicando contexto e dandos significado aos dados;
# 3. Conhecimento: consiste em informações processadas e transformadas em experiência por uma pessoa.
#
# **Tipos de Dados**
#
# * Estruturados: dados com estrutura rígida e previamente definida, formados basicamente por tabelas de banco de dados;
# * Não Estruturados: dados que não requerem estruturas bem definidas ou padronizadas, mais comuns no dia a dia das pessoas, formados por textos, fotos, vídeos, áudios, etc;
# * Semi-estruturados: dados que possuem uma combinação de ambas as características, pois ao mesmo tempo que são de, algum forma, organizados, não são tão rígidos como os dados estruturados, formados por códigos em HTML, XML, JSON, entre outros.
#
# **Etapas Fundamentais**
#
# O processo da análise de dados pode ser dividido em três grandes etapas. São elas:
#
# 1. Levantamento: é a parte da análise onde os dados são coletados e é realizado o entendimento inicial da sua natureza e do negócio em si. Em outras palavras, visa se responder "do que se tratam os dados?".
#
# 2. Exploração: é a parte da análise onde ocorre o aprofundamento e foco no significado e relação entre os dados. Em outras palavras, visa se responder "o que os dados dizem e/ou sugerem?".
#
# 3. Mineração: é a parte da análise onde ocorre um processamento sistemático e metódico para a identificação de padrões e informações implícitas dentro dos dados. Em outras palavras, visa se responder "como extrair informações úteis dos dados?".
#
# Observações:
#
# * As etapas mencionadas acima também podem ser relacionadas com as terminologias de significado.
#
# * Essas etapas são apenas uma proposta lógica de aplicações comumente utilizadas durante o processo de análise de dados. Porém, podem existir outras variações.
#
# * Existe também a etapa de comunicação dos resultados para o cliente ou demais áreas. Esta ocorre ao final da análise completa através de relatórios e paineis interativos, onde são utilizadas diversas ferramentas e conceitos analíticos de BI, ligados ao negócio.
#
# **Tipos de Análise**
#
# A análise de dados pode ser dividida em 4 tipos diferentes. São eles:
#
# 1. Descritiva: visa responder "o que aconteceu?"
# 2. Diagnóstica: visa responder "por que aconteceu?"
# 3. Preditiva: visa responder "o que vai acontecer?"
# 4. Prescritiva: visa responder "o que fazer quando acontecer?"
#
# **Aprendizado de Máquina**
#
# O aprendizado de máquina, ou Machine Learning (ML) em inglês, é uma área dentro da análise de dados que utiliza diversos algoritmos, técnicas de matemática e conceitos estatísticos para criar modelos de indução a partir dos dados coletados e analisados.
#
# Para a sua execução, são utilizados diversos etapas e processamentos intermediários. De modo geral, é possível utilizar o seguinte pipeline para o seu funcionamento:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <figcaption align="center">Fonte: De autoria própria.</figcaption>

# %% [markdown]
# **Análise Exploratória de Dados**
#
# A análise exploratória de dados, ou Exploratory Data Analysis (EDA) em inglês, é uma das etapas do ML onde ocorre, de fato, a análise estatística e o entendimento dos dados por meio das visualizações geradas a partir dos dados coletados.
#
# Dentre as diversas tarefas comuns, destacam-se: o entendimento do comportamento e distribuição dos dados individualmente ou em conjunto, a identificação de anomalias com inconsistências ou dados faltantes (missing values) e pontos extremos (outliers) e uma possível seleção ou criação de novos atributos ou características (features).
#
# Quanto às visualizações geradas nessa etapa, é importante mencionar que não é requisitado um alto nível de qualidade, pois nosso foco no EDA é apenas a apresentação e entendmento básico da natureza dos dados e informações que o conjunto de dados possui. Por isso, visando a economia de tempo, podemos apenas gerar gráficos básicos, tomando um caminho mais direto e menos burocrático. Dessa forma, conseguiremos ter uma dimensão rápida dos dados e ainda poderemos responder a perguntas que surgirem no meio do processo de entendimento dos mesmos.
#
# Essencialmente, a etapa da EDA também pode ser subdividida em subetapas, formando um pipeline próprio, o qual vamos nos aprofundar mais.

# %% [markdown]
# <a id="pipeline_eda"></a>
# ## **Pipeline da EDA**

# %% [markdown]
# <center>
#     <figure>
#         <img src='https://www.researchgate.net/profile/Cristina-Sousa-2/publication/342282008/figure/fig2/AS:903839578353665@1592503556728/Exploratory-Data-Analysis-EDA-steps.png' width='800'/>
#         <figcaption align="center">Fonte: (Taboada et al., 2020)</figcaption>
#     </figure>
# </center>

# %% [markdown]
# Vale mencionar que este diagrama apresentado serve apenas como uma proposta para a prática do EDA. Porém, caso necessário, podem ser utilizadas outras etapas ou até divisões diferentes das que foram adotadas neste material.

# %% [markdown]
# <a id="atributes"></a>
# ### **1. Reconhecimento de Atributos**
#
# Esta etapa consiste no entendimento do dataset de modo geral, relacionando suas dimensões, seus exemplos, representando os registros e entradas, e atributos, representando suas colunas e características. Os atributos, por sua vez, podem ser investigados quanto ao seu tipo, escala, valores únicos, etc. Para esta etapa, é aconselhável também acessar os dicionários dos dados, caso existam, a fim de ter uma dimensão maior da natureza e detalhes importantes dos dados.

# %% [markdown]
# <a id="univariate"></a>
# ### **2. Análise Univariada**
#
# Esta etapa consiste na descrição dos dados avaliando seus atributos, um por vez. Dessa forma, é possível visualizar as distribuições das variáveis e seus respectivos parâmetros estatísticos que os descrevem.

# %% [markdown]
# <a id="multivariate"></a>
# ### **3. Análise Multivariada**
#
# Esta etapa consiste na descrição dos dados avaliando seus atributos em conjunto. Dessa forma, é possível visualizar correlações entre as variáveis e seus respectivos parâmetros estatísticos que os descrevem.

# %% [markdown]
# <a id="aberrant"></a>
# ### **4. Deteção de Anomalias**
#
# Esta etapa consiste na identificação de anomalias nos dados, seja referente a inconsistência do valor medido (exemplo: idade acima de 300 anos), seja a ausência de um valor. É importante mencionar que a ocorrência sistemática de qualquer anomalia pode estar relacionada ao processo de coleta dos dados, algo que, do ponto de vista estatístico, deve ser analisado cuidadosamente e tratado conforme regras específicas, conforme consta no estado da arte.

# %% [markdown]
# <a id="outliers"></a>
# ### **5. Deteção de Outliers**
#
# Esta etapa consiste na identificação de pontos extremos que podem representar algum tipo de anomalia nos dados e interferir nos parâmetros estatísticos. É importante lembrar que nem sempre um outlier é decorrente de um erro ou anomalia, pois simplesmente pode representar um espaço pouco explorado ou com poucos exemplos à disposição no dataset.

# %% [markdown]
# <a id="feature_eng"></a>
# ### **6. Engenharia de Features**
#
# Esta etapa consiste na transformação e criação de novas características no dataset ou, simplesmente, na diminuição de sua dimensionalidade por meio da seleção das características mais relevantes e as que melhor representam a variância dos dados. Esta etapa está diretamente relacionada com o entendimento da natureza dos dados e do negócio. Porém, vale lembrar que nem sempre esta etapa ocorre dentro da EDA, podendo fazer também parte do pré-processamento.

# %% [markdown]
# Observações:
#
# * Uma observação importante nessas etapas é que, em diversos casos, a EDA e o pré-processamento entram num ciclo, onde o que é descoberto em uma etapa é transformado na consequente que, por sua vez, após estas transformações aplicadas, é possível criar novas visualizações e entendimentos complementares sobre os dados originados, novamente na EDA.
#
# * Além disso, as etapas de descoberta de anomalias ou outliers podem ser tratadas ainda na EDA ou, simplesmente, mantidas para que no pré-processamento de dados sejam passadas por uma limpeza e transformação adicionais.

# %% [markdown]
# <a id="hands_on_eda"></a>
# ## **Hands On!**

# %%
# !pip install geobr geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 928.1/928.1 KB 44.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 34.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 52.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.1
#     Uninstalling shapely-2.0.1:
#       Successfully uninstalled shapely-2.0.1
# ...

# %%
import pandas as pd
import numpy as np

import geobr

# visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns


# set some options in pandas
pd.set_option('display.max_columns', 140)
pd.set_option('display.max_rows', 140)


import warnings
warnings.filterwarnings('ignore')

# %%
def gerar_histograma(data_frame,
                     variavel,
                     bins = 30,
                     color = 'red',
                     xlabel = 'Variável',
                     ylabel = 'Frequência',
                     titulo = 'Histograma',
                     fontsize = 15,
                     fontweight = 'bold',
                     figsize = (8,5)
                    ):
    fig, ax = plt.subplots(figsize = figsize)
    ax.hist(data_frame[variavel], bins = bins,
            color = color)
    ax.set(xlabel = xlabel, ylabel = ylabel)
    ax.set_title(titulo, fontsize = fontsize,
                 fontweight = fontweight
                 );


def gerar_painel_barra(data_frame,
                      var,
                      hue,
                      title = '',
                      title_subplot_1 = '',
                      title_subplot_2 = '',
                      legend_subplot_2 = '',
                      xlabel = 'Quantidade',
                      ylabel = '',
                      figsize = (12, 6)
                     ):
    fig, ax = plt.subplots(1, 2, figsize = figsize)
    sns.countplot(data = data_frame,
                  y = var,
                  ax = ax[0])
    sns.countplot(data = data_frame,
                  y = var,
                  hue = hue,
                  ax = ax[1])
    ax[0].set(ylabel = ylabel, xlabel = xlabel, title = title_subplot_1)
    ax[1].set(ylabel = ylabel, xlabel = xlabel, title = title_subplot_2)
    ax[1].legend(title = legend_subplot_2)
    fig.suptitle(title)
    fig.tight_layout(pad = 4)


def box_plot(data, title, xlabel, ylabel, figsize = (12, 5)):
    fig, ax = plt.subplots(figsize = figsize)
    sns.boxplot(data = data, ax = ax)
    ax.set(title = title, xlabel = xlabel, ylabel = ylabel)




def boxplot_por_filtro(filtro, data_frame, order = None):
    'Gera um boxplot com filtro para o eixo x e a variável no eixo y.'
    provas = ['MATEMATICA','CIENCIAS_NATUREZA', 'LINGUAGENS', 'HUMANAS','REDACAO']
    filtro_tratado = ' '.join(filtro.split('_')).capitalize()

    for prova in provas:
        prova_nome_minusculo = prova.lower()
        fig, ax = plt.subplots(figsize = (15, 5))
        sns.boxplot(x = filtro, y = prova, data = data_frame, ax = ax,
                   order = order)
        ax.set(
            xlabel = filtro_tratado,
               ylabel = f'Nota em {prova_nome_minusculo}',
               title = f'Nota em {prova_nome_minusculo} filtrada por {filtro_tratado}')


def check_missing(df):
    import pandas
    if isinstance(df, pandas.core.frame.DataFrame):
        return (((df.isnull().sum()/df.shape[0])*100).round(2)).sort_values(ascending = False)
    return None

def show_percentage_missing(df):
    import matplotlib.pyplot as plt

    missing = check_missing(df)
    plt.figure(figsize = (10, 20))
    plt.barh(y = missing.index, width = missing.values, color = 'darkgray', height = 0.7, align = 'edge')
    plt.xlabel('% of missing values', size = 10)
    plt.ylabel('Columns', size = 10)
    plt.title('Missing Values', fontdict = {'color':'gray', 'weight':'bold', 'size': 12})
    plt.grid(alpha = 0.5)
    plt.show()



def feature_plot_stat(feature, data):
    fig, ax = plt.subplots(1, 3, figsize = (15, 5))
    fig.suptitle(f'Univariate analysis for {feature}')
    sns.histplot(data[feature], kde = True, ax = ax[0])
    ax[0].set_xlabel('Distribution of '+feature)
    sns.boxplot(y = data[feature], ax = ax[1])
    sns.violinplot(x = data[feature], ax = ax[2])
    fig.tight_layout(pad = 3)


def univariate_analysis(features: list, data = pd.DataFrame):
    for feature in features:
        feature_plot_stat(feature, data)

# %%
cols_rename = {
    'Q001': 'escolaridade_pai',
    'Q002': 'escolaridade_mae',
    'Q003': 'ocupacao_pai',
    'Q004': 'ocapacao_mae',
    'Q005': 'pessoas_residencia',
    'Q006': 'renda_mensal_familiar',
    'Q007': 'empregada_domestico',
    'Q008': 'quantidade_banheiros',
    'Q009': 'quantidade_quartos',
    'Q010': 'quantidade_carros',
    'Q011': 'quantidade_moto',
    'Q012': 'geladeira',
    'Q013': 'freezer',
    'Q014': 'maquina_lavar',
    'Q015': 'maquina_secar',
    'Q016': 'microondas',
    'Q017': 'lava_louca',
    'Q018': 'aspirador_po',
    'Q019': 'TV',
    'Q020': 'DVD',
    'Q021': 'TV_assinatura',
    'Q022': 'celular',
    'Q023': 'telefone_fixo',
    'Q024': 'computador',
    'Q025 ': 'internet',
    'TP_DEPENDENCIA_ADM_ESC': 'TIPO_ESCOLA',
    'TP_LOCALIZACAO_ESC':'LOCALIZACAO_ESCOLA',
    'TP_ESCOLA':'TIPO_ESCOLA',
    'NU_NOTA_MT':'MATEMATICA',
    'NU_NOTA_CN':'CIENCIAS_NATUREZA',
    'NU_NOTA_LC':'LINGUAGENS',
    'NU_NOTA_CH':'HUMANAS',
    'NU_NOTA_REDACAO':'REDACAO',
    'IN_TREINEIRO':'TREINEIRO'
    }

cols_drop = ['TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
             'TX_RESPOSTAS_MT', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
             'TX_GABARITO_LC',  'TX_GABARITO_MT',  'SG_UF_PROVA',
             'CO_PROVA_CH', 'CO_PROVA_LC','CO_PROVA_MT', 'CO_PROVA_CN'
       ]

def editar_estado_civil(estado_civil):
    if estado_civil==0:
        return 'Não Informado'
    elif estado_civil==1:
        return 'Solteiro (a)'
    elif estado_civil==2:
        return 'Casado (a)'
    elif estado_civil==3:
        return 'Divorciado (a)'
    else:
        return 'Viúvo (a)'


def editar_sexo(sexo):
    if sexo == 'M':
        return 'Masculino'
    else:
        return 'Feminino'


#def editar_sexo(sexo):
#    if sexo == 'M':
#        return 'Masculino'
#    return 'Feminino'


def editar_cor_raca(cor_raca):
    if cor_raca == 0:
        return 'Não informado'
    elif cor_raca == 1:
        return 'Branca'
    elif cor_raca == 2:
        return 'Preta'
    elif cor_raca == 3:
        return 'Parda'
    elif cor_raca == 4:
        return 'Amarela'
    else:
        return 'Indígena'



def tratar_dados(df):

    # drop de colunas
    df = df.drop(columns = cols_drop)

    # renomear colunas
    df = df.rename(columns = cols_rename)

    #define uma lista das provas que serão analisadas
    provas = ['MATEMATICA','CIENCIAS_NATUREZA', 'LINGUAGENS', 'HUMANAS','REDACAO']

    # trata colunas categóricas
    df['TP_ESTADO_CIVIL'] = df['TP_ESTADO_CIVIL'].apply(editar_estado_civil)
    df['TP_SEXO'] = df['TP_SEXO'].apply(editar_sexo)
    df['TP_COR_RACA'] = df['TP_COR_RACA'].apply(editar_cor_raca)

    # drop de missing
    df = df.dropna(how = 'any', subset = provas)


    return df

# %%
### define uma lista das provas que serão analisadas
provas = ['MATEMATICA','CIENCIAS_NATUREZA', 'LINGUAGENS', 'HUMANAS','REDACAO']

# %%
df_raw = pd.read_csv('dados_enem_2021_BA.csv')
quest  = pd.read_csv('dados_enem_2021_BA_questoes_socieconomicas.csv')
df     = df_raw.merge(quest, on = 'NU_INSCRICAO', how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-14107cd0fd06> in <module>
# ----> 1 df_raw = pd.read_csv('dados_enem_2021_BA.csv')
#       2 quest  = pd.read_csv('dados_enem_2021_BA_questoes_socieconomicas.csv')
#       3 df     = df_raw.merge(quest, on = 'NU_INSCRICAO', how = 'inner')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# Aplicaremos agora técnicas de EDA para compreender os dados do ENEM.

# %%
# aplica a função de tratamento dos dados
df = tratar_dados(df)

# %%
df.head()

# %% [markdown]
# #### Análise Estatística

# %% [markdown]
# Nesta seção faremos algumas visualizações estatísticas com a finalidade de sumarizar os dados e suas relações.

# %%
# filtra os dados para a condição de Treineiro
treineiro = df.query('TREINEIRO == 1')

# %%
var_idade = 'TP_FAIXA_ETARIA'

fig, ax = plt.subplots(3, 2, figsize = (15, 12))
# título da figura
fig.suptitle('Perfil etário dos inscritos no ENEM',
             fontsize = 20, fontweight = 'bold')
# insere um histograma da idade no eixo ax[0,0]
ax[0, 0].hist(df[var_idade], bins = 30)
# altera os labels do eixo ax[0,0]
ax[0, 0].set(xlabel = 'Idade', ylabel = 'Frequência')
ax[0, 0].set_title('Inscritos gerais')
# insere um histograma para a idade dos treineiros no eixo ax[0,1]
ax[0, 1].hist(treineiro[var_idade], bins = 30)
# altera os labels do eix[0,1]
ax[0, 1].set(xlabel = 'Idade', ylabel = 'Frequência')
ax[0, 1].set_title('Treineiro')
# distribuição da idade dos inscritos gerais no eixo ax[1,0] e altera os labels
sns.distplot(df[var_idade], ax = ax[1, 0])
ax[1, 0].set(xlabel = 'Idade', ylabel = 'Frequência', title = 'Inscritos gerais');
# distribuição da idade dos treineiros nos eixo ax[1,1] e altera os labels
sns.distplot(treineiro[var_idade], ax = ax[1, 1])
ax[1, 1].set(xlabel = 'Idade', ylabel = 'Frequência', title = 'Treineiro')
# boxplot da idade no eixo ax[2,0] e altera os labels
sns.boxplot(data = df, x = var_idade, ax = ax[2, 0])
ax[2, 0].set(xlabel = 'Idade', title = 'Inscritos gerais')
# boxplot da idade no eixo ax[2,1] e altera os labels
sns.boxplot(data = treineiro, x = var_idade, ax = ax[2, 1])
ax[2, 1].set(xlabel = 'Idade', title = 'Treineiro')
plt.tight_layout(pad = 4)

# %% [markdown]
# Perfil de gênero

# %%
fig, ax = plt.subplots(figsize = (8, 5))
sns.countplot(data = df, x = 'TP_SEXO',ax = ax)
ax.set(xlabel = 'Sexo', ylabel = 'Quantidade')
ax.set_title('Proporção entre os gêneros');

# %% [markdown]
# Estado civil

# %%
fig, ax = plt.subplots(1,2, figsize = (12, 6))
sns.countplot(data = df,
             y = 'TP_ESTADO_CIVIL', ax = ax[0])
sns.countplot(data = df,
             y = 'TP_ESTADO_CIVIL', hue = 'TP_SEXO', ax = ax[1])
ax[0].set(ylabel = 'Estado Civil', xlabel = 'Quantidade',title = 'Estado civil')
ax[1].set(ylabel = 'Estado Civil', xlabel = 'Quantidade',title = 'Estado civil por gênero')
ax[1].legend(title = 'Gênero')
fig.suptitle('Estado civil dos inscritos')
fig.tight_layout(pad = 4);

# %% [markdown]
# Cor, raça e nacionalidade

# %%
gerar_painel_barra(df, 'TP_COR_RACA', 'TP_SEXO',
                   title = 'Perfil de cor e raça dos inscritos',
                   title_subplot_1 = 'Cor/raça',
                   title_subplot_2 = 'Cor/raça por gênero',
                   legend_subplot_2 = 'Gênero',
                   ylabel = 'Cor/raça')

# %%
# análise univariada das provas
univariate_analysis(provas , data = df)

# %%
# heatmap das provas
fig, ax = plt.subplots()
corr_provas = df[provas].corr()
sns.heatmap(corr_provas, annot=True, cmap = 'Blues', ax = ax);

# %%
figure = sns.pairplot(df[provas+['TP_SEXO']], hue = 'TP_SEXO');

# %%
fig, ax = plt.subplots(figsize = (10, 10))
sns.boxplot(data = df[provas], ax = ax);
# sns.boxplot(data = df[provas], showfliers = False)

# %% [markdown]
# * Desempenho escolar por renda familiar

# %%
renda_ordenada = df['renda_mensal_familiar'].unique()
renda_ordenada.sort()
boxplot_por_filtro('renda_mensal_familiar', df, renda_ordenada)

# %% [markdown]
# * Desempenho por escolaridade da mãe

# %%
escolaridade_mae_ordenada = df['escolaridade_mae'].unique()
escolaridade_mae_ordenada.sort()
boxplot_por_filtro('escolaridade_mae', df, escolaridade_mae_ordenada)

# %% [markdown]
# * Escolaridade Pai

# %%
escolaridade_pai_ordenada = df['escolaridade_pai'].unique()
escolaridade_pai_ordenada.sort()
boxplot_por_filtro('escolaridade_pai', df, escolaridade_pai_ordenada)

# %% [markdown]
# **ENEM visão município e Análise Geoespacial**

# %%
df_visao_municipio = (
    df_raw
    .query('NU_NOTA_MT != 0 ')
    .groupby(by = ['NO_MUNICIPIO_PROVA', 'CO_MUNICIPIO_PROVA'], as_index = False)['NU_NOTA_MT']
    .agg([np.min, np.mean, np.median, np.max])
    .reset_index(drop = False)
    .rename(
        columns = {
            'CO_MUNICIPIO_PROVA' : 'COD_IBGE',
            'NO_MUNICIPIO_PROVA': 'Município',
            'amin' : 'Mínimo_MT',
            'mean' : 'Média_MT',
            'median' : 'Mediana_MT',
            'amax' : 'Máximo_MT'
                  })
    .sort_values(by = ['Máximo_MT', 'Média_MT', 'Mediana_MT'], ascending = False)
    .reset_index(drop = True)
)


df_quantidade_inscritos = (
    df_raw.groupby(by = ['NO_MUNICIPIO_PROVA', 'CO_MUNICIPIO_PROVA'], as_index = False)['NU_INSCRICAO']
    .count()
    .rename(columns = {'NO_MUNICIPIO_PROVA' : 'Município',
                       'CO_MUNICIPIO_PROVA' : 'COD_IBGE',
                       'NU_INSCRICAO' : 'Quantidade_inscritos'
                      })
    .sort_values(by = ['Quantidade_inscritos'], ascending = False)
    .reset_index(drop = True)
)

total = df_quantidade_inscritos.Quantidade_inscritos.sum()

df_quantidade_inscritos['Percentual_inscritos'] = (df_quantidade_inscritos.Quantidade_inscritos / total * 100).round(2)

df_quantidade_inscritos['NU_ANO'] = 2021

df_municipio = pd.merge(
    df_visao_municipio.drop(columns = ['Município']),
    df_quantidade_inscritos,
    on = 'COD_IBGE',
    how = 'inner'
)

# %%
df_municipio.head()

# %% [markdown]
# * Quantidade Inscritos por Município

# %%
(df_municipio
 .nlargest(n = 20, columns = 'Quantidade_inscritos')
 .set_index('Município')['Quantidade_inscritos']
 .plot(kind = 'barh')
)

# %% [markdown]
# * Análise espacial

# %%
# municípios BA
ba_muni = geobr.read_municipality(code_muni="BA", year=2010)

# %%
# !pip install descartes

# %%
# plot
fig, ax = plt.subplots(figsize=(5, 5), dpi = 150)

ba_muni.plot(facecolor="#2D3E50", edgecolor="#FEBF57",linewidth = 0.3,  ax=ax)

ax.set_title("Municípios BA, 2010", fontsize=4)
ax.axis("off")

# %%
ba_muni.head(1)

# %%
df_spatial_enem = ba_muni.merge(df_municipio,
                                left_on  = 'code_muni',
                                right_on = 'COD_IBGE',
                                how = 'left')

# %%
# verifica volumetria
df_municipio.shape, ba_muni.shape, df_spatial_enem.shape

# %%
df_spatial_enem.isna().sum()

# %%
df_spatial_enem = df_spatial_enem.fillna(-999)

# %%
df_spatial_enem.isna().sum()

# %% [markdown]
# * Quantidade de inscritos no ENEM por município

# %%
plt.rcParams.update({"font.size": 5})

fig, ax = plt.subplots(figsize=(4, 4), dpi = 150)

df_spatial_enem.plot(
    column="Quantidade_inscritos",
    cmap="Blues",
    legend=True,
    edgecolor="gray",
    linewidth = 0.3,
    legend_kwds={
        "label": "Quantidade de inscritos",
        "orientation": "vertical",
        "shrink": 0.3,
    },
    ax=ax,
)

ax.set_title("Inscritos por município no ENEM - BA, 2021")
ax.axis("off")

# %%
plt.rcParams.update({"font.size": 5})

fig, ax = plt.subplots(figsize=(4, 4), dpi = 150)

df_spatial_enem.plot(
    column="Máximo_MT",
    cmap="Blues",
    legend=True,
    edgecolor="gray",
    linewidth = 0.3,
    legend_kwds={
        "label": "Quantidade de inscritos",
        "orientation": "vertical",
        "shrink": 0.3,
    },
    ax=ax,
)

ax.set_title("Inscritos por município no ENEM - BA, 2021")
ax.axis("off")

# %% [markdown]
# <a id="homework"></a>
# ## **Homework**

# %% [markdown]
# Estudo de Caso: Dados da SAEB.
#
# Nessa parte prática da aula, vamos explorar um pouco os dados referentes ao Sistema de Avaliação da Educação Básica (SAEB), disponibilizados pelo Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira (INEP).
#
# Inicialmente, como em qualquer análise, temos que compreender o contexto dos dados que estamos analisando. Por isso, faremos uma breve introdução sobre a natureza e a origem do conjunto de dados

# %% [markdown]
# <a id="hands_on_atributes"></a>
# ### **0. Introdução**

# %% [markdown]
# Esta é uma parte que antecede qualquer exploração de dados e visa esclarecer o contexto e objetivos com os quais conduziremos nossa análise. Para isso, inicialmente, faremos o entendimento do negócio e, após isso, poderemos preparar o ambiente de desenvolvimento e coletar os dados, implementando um processo sistemático de extração e integração dos dados para análises (EDA) e transformações futuras (pré-processamento, indução de modelos de ML, etc), compondo o processo que chamamos comumente de ETL (extração, transformação e carregamento).

# %% [markdown]
# <a id="hands_on_intro_business"></a>
# #### **0.1 Entendimeto do Negócio**

# %% [markdown]
# ##### Contexto dos Dados
#
# O objetivo do SAEB é estabelecer um processo periódico de avaliação da qualidade do ensino baseado no desempenho dos alunos, nas condições de infraestrutura física das instituições, no corpo docente, formatos de gestão, recursos pedagógicos e situações de acessibilidade.
#
# Para isso, são aplicados questionários a estudantes, professores, diretores de escolas e dirigentes municipais de educação. Estes questionários também seguem os pressupostos do Plano Nacional de Educação (PNE).
#
# A partir dessas definições, foi construída a Matriz de Referência para o SAEB que define a qualidade da educação a partir de sete eixos, conforme constam na legislação educacional. É possível visualizar o esquema na imagem abaixo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <figcaption align="center">Fonte: (Brasil. MEC/INEP, 2021)</figcaption>

# %% [markdown]
# ##### Últimas Atualizações
#
# Até o ano de 2019, os dados coletados eram compostos por tipos de avaliação distintos, com propósitos distintos. Eram os seguintes:  ANEB, ANRESC e ANA. É possível visualizar esta composição na imagem abaixo.
#
# Atualmente, estas categorias estão unificadas em um local apenas, o site oficial da SAEB, incluindo avaliações de ensino infantil, fundamental e médio.

# %% [markdown]
# <center>
#     <figure>
#         <img src='https://miro.medium.com/max/1400/0*YtkFbKWg4cOijn0V' width='300'/>
#         <figcaption align="center">Fonte: (Melo et al., 2019)</figcaption>
#     </figure>
# </center>

# %% [markdown]
# ##### Arquivos dos Dados
#
# Especificamente, os dados de 2021 são compostos por dois grandes conjuntos de dados:
#
# 1. Educação Infantil (TS_EDUCACAO_INFANTIL_2021.csv): dados das turmas selecionadas para compor a amostra, coletados por meio de questionários aplicados a professores e a diretores;
#
# 2. Secretário Municipal (TS_SECRETARIO_MUNICIPAL_2021.csv): dados dos órgãos gestores municipais da educação, coletados por meio de questionários aplicados aos secretários municipais de educação.

# %% [markdown]
# ##### Informações Adicionais
#
# Para descritivos complementares sobre os dados e sua coleta, é possível acessar o arquivo Leia-me anexado junto aos dados.
#
# A partir dessa pequena introdução e, tendo em vista que os dados foram coletados corretamente do ponto de vista estatístico e amostral, vamos dar sequência com a coleta dos dados e possíveis integracões entre diferentes fontes de dados.

# %% [markdown]
# ##### Principais Objetivos
#
# Como objetivos da nossa análise de dados, podemos explorar as transformações ocorridas durante e em decorrência da pandemia e compreender o cenário como um todo no que diz respeito a participação do público nas pesquisas realizadas, quanto a sexo, raça, idade e demais partições.
#
#
# Assim, o objetivo deste case é apresentar uma análise exploratória dos dados, bem como todos os procedimentos necessários para a junção, limpeza e manipulação dos dados, aplicando-se o pipeline de EDA visto em sala de aula.
#
#
# **Entregável: PPT não técnico descrevendo os principais resultados da análise exploratória de dados e os arquivos em python contendo todos os steps adotados.**
#
#
# Os dados podem ser extraídos no site de microdados do INEP.

# %% [markdown]
# <a id="next_steps"></a>
# ## **Para aprofundar**
#
# Após a utilização dos comandos básicos no Pandas para a análise exploratória de dados, foi possível esclarecer de forma prática os conceitos abordados inicialmente.
#
# Como material complementar, existem outras bibliotecas que auxiliam e até automatizam a tarefa da EDA. São elas:
# - DataPrep (https://dataprep.ai/)
# - Pandas Profiling (https://pandas-profiling.ydata.ai/docs/master/index.html)
# - SweetViz (https://github.com/fbdesignpro/sweetviz)
# - AutoViz (https://github.com/AutoViML/AutoViz)
#
# Seria interessante investigar e buscar mais detalhes sobre essas bibliotecas e entender como utilizá-las no dia a dia para a tarefa de EDA e aproveitá-las, encurtando o caminho da análise e tornando-a parte integral do pipeline de análise de dados e ML.
#
# As bibliotecas mencionadas podem também oferecer mais robustez e garantir detecções de anomalias mais apuradas e maior geração de insights sobre os dados analisados.
#
# Vale lembrar também que o entendimento do negócio e a execução de possíveis transformações nos dados, necessárias para a consistência dos mesmos, ainda exigem a utilização das práticas mais básicas com as bibliotecas que vimos na parte prática, como Numpy e Pandas.

# %% [markdown]
# <a id="ref"></a>
# ## **Referências**
#
# [Saeb - Microdados do Sistema de Avaliação da Educação Básica](https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/saeb)
#
# [Dados, informação e conhecimento: qual a diferença dos conceitos?](https://www.certifiquei.com.br/dados-informacao-conhecimento/)
#
# [Dados estruturados, não-estruturados e semiestruturados: diferenças e similaridades](https://esr.rnp.br/ciencia-de-dados/dados-estruturados-nao-estruturados-e-semiestruturados/)
#
# [Iniciando uma Análise Exploratória dos Dados da Avaliação Nacional da Educação Básica](https://medium.com/@elvismelo/iniciando-uma-análise-exploratória-dos-dados-da-avaliação-nacional-da-educação-básica-187b3b215481)
#
# [Análise descritiva de dados - SAEB](https://rpubs.com/caspgalvao/me2_saeb)
#
# [Rosalina Soares reflete sobre o Saeb 2021](https://www.frm.org.br/conteudo/educacao-basica/noticia/rosalina-soares-reflete-sobre-o-saeb-2021)
#
# [Exploratory Data Analysis and Data Envelopment Analysis of Construction and Demolition Waste Management in the European Economic Area](https://www.researchgate.net/publication/342282008_Exploratory_Data_Analysis_and_Data_Envelopment_Analysis_of_Construction_and_Demolition_Waste_Management_in_the_European_Economic_Area)
#
# [Exploratory Data Analysis in Python — A Step-by-Step Process](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# [Exploratory data analysis](https://datascienceguide.github.io/exploratory-data-analysis)
#
# [Análise Exploratória de Dados com Python](https://medium.com/@aasouzaconsult/python-para-análise-de-dados-24028d7013b3)
#
# [API de serviço de dados](https://servicodados.ibge.gov.br/api/docs)
#
# [4 Tools to Speed Up Exploratory Data Analysis (EDA) in Python](https://builtin.com/data-science/EDA-python)
#
# [NumPy](https://numpy.org/doc/stable/)
#
# [Pandas](https://pandas.pydata.org/docs/)
#
# [Scikit-Learn](https://scikit-learn.org/stable/tutorial/index.html)
#
# [Matplotlib](https://matplotlib.org/stable/tutorials/index)
#
# [Seaborn](https://seaborn.pydata.org/tutorial.html)
